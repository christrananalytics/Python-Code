# %%
import pandas as pd

soccer_fans = pd.read_csv('Soccer_Fantasy.csv')
soccer_fans.head(10)
# Out:
#    player_id position        first_name    last_name Cost  \
# 0          1        GK            David       Ospina  4.8
# 1          2        GK             Petr         Cech  5.3
# 2          3        GK  Damian Emiliano     Martinez  4.0
# 3          4       DEF          Laurent    Koscielny  6.0
# 4          5       DEF              Per  Mertesacker  4.7
# 5          6       DEF  Gabriel Armando     de Abreu  5.0
# 6          7       DEF           Héctor     Bellerín  5.9
# 7          9       DEF             Carl    Jenkinson  4.5
# 8         10       DEF            Nacho      Monreal  5.7
# 9         11       DEF              Rob      Holding  4.4
#
#    selected_by_percent  total_points  points_per_game  Minutes_Played  \
# 0                  0.2            19              3.8             380
# 1                  4.5           124              3.6            3039
# 2                  0.6             0              0.0               0
# ...

# %%
soccer_fans.sort_values('Cost').head(5)
# Out:
#      player_id position         first_name  last_name  Cost  \
# 22          28       FWD         Alexandre  Lacazette  10.3
# 334        252       MID             Kevin  De Bruyne  10.3
# 147        472       FWD            Álvaro     Morata  10.4
# 340        259       FWD  Gabriel Fernando   de Jesus  10.4
# 134        104       MID              Eden     Hazard  10.5
#
#      selected_by_percent  total_points  points_per_game  Minutes_Played  \
# 22                   7.6           138              4.3            2197
# 334                 21.4           209              5.6            3073
# 147                  7.6           122              3.9            2055
# 340                 17.1           126              4.3            1660
# 134                  6.4           173              5.1            2417
#
#      Goals_scored  ...  Unnamed: 187  Unnamed: 188  Unnamed: 189  \
# 22             14  ...           NaN           NaN           NaN
# ...

# %%
soccer_fans.sort_values('total_points')['last_name'].head(10)
# Out:
# 646             Diangana
# 122              O'Neill
# 444              Muniesa
# 126    dos Reis Carvalho
# 434               Taylor
# 424               Clasie
# 409              Woodman
# 400              de Jong
# 398               Murphy
# 140       Da Silva Costa
# Name: last_name, dtype: object

# %%
import statsmodels.formula.api as smf 

#md = smf.ols(formula = 'selected_by_percent ~ total_points', data = soccer_fans)

#results = md.fit()

import matplotlib.pyplot as plt
plt.plot(soccer_fans['total_points'], soccer_fans['selected_by_percent'], 'o')
plt.axhline(y=0, color = 'black')
plt.xlabel('Total Points')
plt.ylabel('Selected b Percentage')
plt.grid()

# %%
import matplotlib.pyplot as plt
plt.plot(soccer_fans['total_points'], soccer_fans['Cost'], 'o')
plt.axhline(y=0, color = 'black')
plt.xlabel('Total Points')
plt.ylabel('Cost')
plt.grid()
